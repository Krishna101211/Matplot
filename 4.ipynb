# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishna101211/Matplot/blob/main/4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,15,20,25,30]
z=[15,20,25,30,35]

plt.subplot(1,2,1)
plt.plot(x,y)

plt.subplot(1,2,2)
plt.plot(y,z)
http://plt.show()

'''
'''
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,15,20,25,30]
z=[15,20,25,30,35]
plt.figure(figsize=(10,15))
plt.subplot(2,2,1)
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("G1")

plt.subplot(2,2,2)
plt.plot(x,z)
plt.xlabel("x")
plt.ylabel("z")
plt.title("G2")

plt.subplot(2,2,3)
plt.plot(y,z)
plt.xlabel("y")
plt.ylabel("z")
plt.title("G3")

plt.subplot(2,2,4)
plt.plot(y,z)
plt.xlabel("y")
plt.ylabel("z")
plt.title("G4")
plt.suptitle("All Grapgh")
http://plt.show()
'''

import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,15,20,25,30]
z=[15,20,25,30,35]
plt.figure(figsize=(10,15))
plt.subplot(2,2,1)
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("G1")

plt.subplot(2,2,2)
plt.scatter(x,z)
plt.xlabel("x")
plt.ylabel("z")
plt.title("G2")

plt.subplot(2,2,3)
plt.bar(y,z)
plt.xlabel("y")
plt.ylabel("z")
plt.title("G3")

plt.subplot(2,2,4)
plt.pie(y,labels=["a","b","c","d","e"],autopct="%1.0f%%")
plt.title("G4")
plt.suptitle("All Grapgh")
plt.show()
